# %% [markdown]
# # Sentiment analysis with KNN
#
# ### Some plotting functions

# %%
# !git clone https://github.com/s7s/machine_learning_1.git
# %cd  machine_learning_1/KNN
# Out:
# Cloning into 'machine_learning_1'...
# remote: Enumerating objects: 370, done.
# remote: Counting objects: 100% (118/118), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 370 (delta 68), reused 3 (delta 1), pack-reused 252 (from 1)
# Receiving objects: 100% (370/370), 42.70 MiB | 13.45 MiB/s, done.
# Resolving deltas: 100% (191/191), done.
# /content/machine_learning_1/KNN

# %%
# Importing packages
from matplotlib import pyplot as plt
import numpy as np
import random
import utils

# %%
import numpy as np
features = np.array([[1,0],[0,2],[1,1],[1,2],[1,3],[2,2],[3,2],[2,3]])
labels = np.array([0,0,0,0,1,1,1,1])

# %%
# Plotting the points
utils.plot_points(features, labels)

# %% [markdown]
# # KNN SKlearn

# %%
from sklearn.neighbors import KNeighborsClassifier
# use KNeighborsClassifier with n_neighbors=3 to predict the class of the point(1.5,2)
krr = KNeighborsClassifier(n_neighbors = 3 )
krr.fit(features, labels)
krr.predict([[1.5,2]])
# Out:
# array([0])

# %%
from sklearn.neighbors import KNeighborsClassifier
# use KNeighborsClassifier with n_neighbors=5 to predict the class of the point(1.5,2)
krr = KNeighborsClassifier(n_neighbors = 5 )
krr.fit(features, labels)
krr.predict([[1.5,2]])
# Out:
# array([1])
